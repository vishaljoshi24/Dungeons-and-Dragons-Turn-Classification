# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/DungeonsAndDragonsTurnClassification/blob/Codex-Branch/TwoAgents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b Codex-Branch https://github.com/vishaljoshi24/DungeonsAndDragonsTurnClassification/
# %cd /content/DungeonsAndDragonsTurnClassification
# Out:
# Cloning into 'DungeonsAndDragonsTurnClassification'...
# remote: Enumerating objects: 515, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 515 (delta 116), reused 77 (delta 64), pack-reused 348 (from 2)
# Receiving objects: 100% (515/515), 3.13 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (296/296), done.
# /content/DungeonsAndDragonsTurnClassification

# %%
# !pip install dspy
# Out:
# Collecting dspy
#   Downloading dspy-3.2.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.43.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.11.9)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.67.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.32.4)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.13.4)
# Collecting litellm>=1.64.0 (from dspy)
#   Downloading litellm-1.90.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.9 MB/s eta 0:00:00
# Collecting diskcache>=5.6.0 (from dspy)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting json-repair>=0.54.2 (from dspy)
#   Downloading json_repair-0.61.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (9.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy) (4.14.0)
# Collecting asyncer==0.0.8 (from dspy)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (6.2.6)
# Requirement already satisfied: cloudpickle>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.7.1)
# Collecting gepa==0.0.27 (from gepa[dspy]==0.0.27->dspy)
#   Downloading gepa-0.0.27-py3-none-any.whl.metadata (30 kB)
# Collecting typeguard==4.4.3 (from dspy)
#   Downloading typeguard-4.4.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard==4.4.3->dspy) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy) (3.18)
# Collecting fastuuid<1.0,>=0.14.0 (from litellm>=1.64.0->dspy)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.28.1)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (1.2.2)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.13.0)
# Collecting importlib-metadata<9.0,>=8.0.0 (from litellm>=1.64.0->dspy)
#   Downloading importlib_metadata-8.9.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.4.2)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.1.6)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.14.1)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2026.6.17)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.24.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm>=1.64.0->dspy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm>=1.64.0->dspy) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm>=1.64.0->dspy) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0,>=3.1.6->litellm>=1.64.0->dspy) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (2026.5.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (1.20.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (0.25.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (0.1.2)
# Downloading dspy-3.2.1-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 9.9 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.27-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.5/146.5 kB 16.3 MB/s eta 0:00:00
# Downloading typeguard-4.4.3-py3-none-any.whl (34 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.8 MB/s eta 0:00:00
# Downloading json_repair-0.61.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.2 MB/s eta 0:00:00
# Downloading litellm-1.90.2-py3-none-any.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 129.4 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 26.0 MB/s eta 0:00:00
# Downloading importlib_metadata-8.9.0-py3-none-any.whl (27 kB)
# Installing collected packages: typeguard, json-repair, importlib-metadata, gepa, fastuuid, diskcache, asyncer, litellm, dspy
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.5.2
#     Uninstalling typeguard-4.5.2:
#       Successfully uninstalled typeguard-4.5.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 9.0.0
#     Uninstalling importlib_metadata-9.0.0:
#       Successfully uninstalled importlib_metadata-9.0.0
# Successfully installed asyncer-0.0.8 diskcache-5.6.3 dspy-3.2.1 fastuuid-0.14.0 gepa-0.0.27 importlib-metadata-8.9.0 json-repair-0.61.1 litellm-1.90.2 typeguard-4.4.3

# %%
import argparse

# %%
from modules import  (
    AgentProfile,
    TwoAgentConversation,
    configure_lm,
    PromptTool,
    InstructedChatbot
)

# %%
DEFAULT_SCENARIO = (
    'This D&D short scenario specifically concerns a rat infestation.'
'It is set in the craft brewery Company and is in dire need of help.'
'Alice and Bob are here to sort out a RAT INFESTATION in the brewery\'s BASEMENT.'
'For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the brewery'
'At the beginning of this adventure Alice and Bob'
'meet in the Wizard Tower Brewing Company. These two adventurers'
'DO NOT know each other AT FIRST and need to get to know each other.'
'The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.'
)

# %%
instructions_path = "instructions.xlsx"
prompt_tool = PromptTool(prompts_path=instructions_path)

# %%
def build_conversation() -> TwoAgentConversation:
    alice = AgentProfile(
        name="Alice",
        character="Alice, a dwarf barbarian.",
        instructions=(
          'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        'play the role of a character named Alice. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with with the user who is the '
        'other player, on the task at hand.'
        'Always use first-person limited perspective.'
        ),
    )
    bob = AgentProfile(
        name="Bob",
        character="Bob, a wizard.",
        instructions=(
        'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        'play the role of a character named Bob. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with with the user who is the '
        'other player, on the task at hand.'
        'Always use first-person limited perspective.'
        ),
    )
    return TwoAgentConversation(
        agent_a=alice,
        agent_b=bob,
        scenario=DEFAULT_SCENARIO,
        chatbot_a=InstructedChatbot(prompt_tool=prompt_tool),
        chatbot_b=InstructedChatbot(prompt_tool=prompt_tool),
    )

# %%
parser = argparse.ArgumentParser(description="Run two D&D DSPy agents together.")

# %%
parser.add_argument(
    "--opening-message",
    default="I think we should inspect the basement door before we rush in.",
    help="The first turn spoken by Alice.",
)
# Out:
# _StoreAction(option_strings=['--opening-message'], dest='opening_message', nargs=None, const=None, default='I think we should inspect the basement door before we rush in.', type=None, choices=None, required=False, help='The first turn spoken by Alice.', metavar=None)

# %%
parser.add_argument(
    "--rounds",
    type=int,
    default=4,
    help="Number of replies to generate after the opening message.",
)
# Out:
# _StoreAction(option_strings=['--rounds'], dest='rounds', nargs=None, const=None, default=4, type=<class 'int'>, choices=None, required=False, help='Number of replies to generate after the opening message.', metavar=None)

# %%
parser.add_argument("--model", default="ollama_chat/qwen3:8b")
# Out:
# _StoreAction(option_strings=['--model'], dest='model', nargs=None, const=None, default='ollama_chat/qwen3:8b', type=None, choices=None, required=False, help=None, metavar=None)

# %%
parser.add_argument("--api-base", default="http://localhost:11434")
# Out:
# _StoreAction(option_strings=['--api-base'], dest='api_base', nargs=None, const=None, default='http://localhost:11434', type=None, choices=None, required=False, help=None, metavar=None)

# %%
args = parser.parse_args([])

# %%
configure_lm(model=args.model, api_base=args.api_base)

# %%
conversation = build_conversation()

# %%
for turn in conversation.run(args.opening_message, rounds=args.rounds):
    print(turn)
# Out:
# Alice: I think we should inspect the basement door before we rush in.
# Bob: "Agreed. A magical lock or ward might be in place to deter... *sniffs the air* ...unwanted guests. Let me cast *Detect Magic* to check for residual enchantments."
# Alice: "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
# Bob: "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
# Alice: "Lead the way, Bob. If the magic reveals anything worth breaking, I'll smash it. But if it's just a regular lock… well, I've torn down worse in a dwarven mine."

# %%
import dspy
dspy.inspect_history(n=4)
# Out:
# [2026-07-02T15:40:04.956387]
#
# System message:
#
# Your input fields are:
# 1. `instruct_prompt` (str):
# 2. `scenario_context` (str):
# 3. `user_input` (str):
# 4. `trajectory` (str):
# Your output fields are:
# 1. `next_thought` (str):
# 2. `next_tool_name` (Literal['classify_input', 'search_prompts', 'update_prompt', 'finish']):
# 3. `next_tool_args` (dict[str, Any]):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## instruct_prompt ## ]]
# {instruct_prompt}
#
# [[ ## scenario_context ## ]]
# {scenario_context}
#
# [[ ## user_input ## ]]
# {user_input}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## next_thought ## ]]
# {next_thought}
#
# [[ ## next_tool_name ## ]]
# {next_tool_name}        # note: the value you produce must exactly match (no extra characters) one of: classify_input; search_prompts; update_prompt; finish
#
# [[ ## next_tool_args ## ]]
# {next_tool_args}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Respond as a D&D player character using the supplied scenario and behaviour instructions.
#
#         You are an Agent. In each episode, you will be given the fields `instruct_prompt`, `scenario_context`, `user_input` as input. And you can see your past trajectory so far.
#         Your goal is to use one or more of the supplied tools to collect any necessary information for producing `response`.
#
#         To do this, you will interleave next_thought, next_tool_name, and next_tool_args in each turn, and also when finishing the task.
#         After each tool call, you receive a resulting observation, which gets appended to your trajectory.
#
#         When writing next_thought, you may reason about the current situation and plan for future steps.
#         When selecting the next_tool_name and its next_tool_args, the tool must be one of:
#
#         (1) classify_input, whose description is <desc>Classify a player's input into a D&D behaviour category.</desc>. It takes arguments {'context': {'type': 'string'}, 'query': {'type': 'string'}, 'user_id': {'type': 'string', 'default': 'default_user'}}.
#         (2) search_prompts, whose description is <desc>Find the instruction text for a classified player behaviour.</desc>. It takes arguments {'prompt_class': {'type': 'string'}, 'context': {'type': 'string'}, 'query': {'type': 'string'}, 'user_id': {'type': 'string', 'default': 'default_user'}, 'limit': {'type': 'integer', 'default': 4}}.
#         (3) update_prompt, whose description is <desc>Append retrieved instructions to the current agent prompt.</desc>. It takes arguments {'context': {'type': 'string'}, 'query': {'type': 'string'}, 'instruct_prompt': {'type': 'string'}, 'prompt_text': {'type': 'string'}, 'new_prompt': {'type': 'string', 'default': ''}}.
#         (4) finish, whose description is <desc>Marks the task as complete. That is, signals that all information for producing the outputs, i.e. `response`, are now available to be extracted.</desc>. It takes arguments {}.
#         When providing `next_tool_args`, the value inside the field must be in JSON format
#
#
# User message:
#
# [[ ## instruct_prompt ## ]]
# You are playing a Dungeons & Dragons scene.
# Character: Bob, a wizard.
# The instructions for how to play the role of a D&D player are as follows. This is a short scenario in which you play the role of a character named Bob. This scenario is structured as a Dungeons & Dragons game. The goal is to be consistent, but creative. It is important to play the role of a Dungeons & Dragons player as accurately as possible, i.e., by responding in ways that you think it is likely a player would respond, and taking into account all information that you have. It is important that you collaborate with with the user who is the other player, on the task at hand.Always use first-person limited perspective.
# Stay in character and reply with only the next spoken turn.
#
# [[ ## scenario_context ## ]]
# This D&D short scenario specifically concerns a rat infestation.It is set in the craft brewery Company and is in dire need of help.Alice and Bob are here to sort out a RAT INFESTATION in the brewery's BASEMENT.For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the breweryAt the beginning of this adventure Alice and Bobmeet in the Wizard Tower Brewing Company. These two adventurersDO NOT know each other AT FIRST and need to get to know each other.The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.
#
# Recent turns:
# Alice: I think we should inspect the basement door before we rush in.
# Bob: "Agreed. A magical lock or ward might be in place to deter... *sniffs the air* ...unwanted guests. Let me cast *Detect Magic* to check for residual enchantments."
# Alice: "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
#
# [[ ## user_input ## ]]
# "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
#
# [[ ## trajectory ## ]]
#
#
# Respond with the corresponding output fields, starting with the field `[[ ## next_thought ## ]]`, then `[[ ## next_tool_name ## ]]` (must be formatted as a valid Python Literal['classify_input', 'search_prompts', 'update_prompt', 'finish']), then `[[ ## next_tool_args ## ]]` (must be formatted as a valid Python dict[str, Any]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## next_thought ## ]]
# Alice's response indicates she's prepared to handle the lock. I should respond in character as Bob, acknowledging her readiness and perhaps suggesting moving forward. Since the scenario is already set, no additional tools are needed.
#
# [[ ## next_tool_name ## ]]
# finish
#
# [[ ## next_tool_args ## ]]
# {}
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-07-02T15:40:23.361381]
#
# System message:
#
# Your input fields are:
# 1. `instruct_prompt` (str):
# 2. `scenario_context` (str):
# 3. `user_input` (str):
# 4. `trajectory` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `response` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## instruct_prompt ## ]]
# {instruct_prompt}
#
# [[ ## scenario_context ## ]]
# {scenario_context}
#
# [[ ## user_input ## ]]
# {user_input}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## response ## ]]
# {response}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Respond as a D&D player character using the supplied scenario and behaviour instructions.
#
#
# User message:
#
# [[ ## instruct_prompt ## ]]
# You are playing a Dungeons & Dragons scene.
# Character: Bob, a wizard.
# The instructions for how to play the role of a D&D player are as follows. This is a short scenario in which you play the role of a character named Bob. This scenario is structured as a Dungeons & Dragons game. The goal is to be consistent, but creative. It is important to play the role of a Dungeons & Dragons player as accurately as possible, i.e., by responding in ways that you think it is likely a player would respond, and taking into account all information that you have. It is important that you collaborate with with the user who is the other player, on the task at hand.Always use first-person limited perspective.
# Stay in character and reply with only the next spoken turn.
#
# [[ ## scenario_context ## ]]
# This D&D short scenario specifically concerns a rat infestation.It is set in the craft brewery Company and is in dire need of help.Alice and Bob are here to sort out a RAT INFESTATION in the brewery's BASEMENT.For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the breweryAt the beginning of this adventure Alice and Bobmeet in the Wizard Tower Brewing Company. These two adventurersDO NOT know each other AT FIRST and need to get to know each other.The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.
#
# Recent turns:
# Alice: I think we should inspect the basement door before we rush in.
# Bob: "Agreed. A magical lock or ward might be in place to deter... *sniffs the air* ...unwanted guests. Let me cast *Detect Magic* to check for residual enchantments."
# Alice: "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
#
# [[ ## user_input ## ]]
# "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
#
# [[ ## trajectory ## ]]
# [[ ## thought_0 ## ]]
# Alice's response indicates she's prepared to handle the lock. I should respond in character as Bob, acknowledging her readiness and perhaps suggesting moving forward. Since the scenario is already set, no additional tools are needed.
#
# [[ ## tool_name_0 ## ]]
# finish
#
# [[ ## tool_args_0 ## ]]
# {}
#
# [[ ## observation_0 ## ]]
# Completed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## response ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Alice's confidence in handling the lock gives me an opportunity to reinforce our teamwork. As a wizard, I should acknowledge her expertise while subtly positioning myself to support her actions. The mention of dwarven mines hints at her experience with structural challenges, so my response should balance respect for her skills with my own role as a spellcaster.
#
# [[ ## response ## ]]
# "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-07-02T15:40:47.851345]
#
# System message:
#
# Your input fields are:
# 1. `instruct_prompt` (str):
# 2. `scenario_context` (str):
# 3. `user_input` (str):
# 4. `trajectory` (str):
# Your output fields are:
# 1. `next_thought` (str):
# 2. `next_tool_name` (Literal['classify_input', 'search_prompts', 'update_prompt', 'finish']):
# 3. `next_tool_args` (dict[str, Any]):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## instruct_prompt ## ]]
# {instruct_prompt}
#
# [[ ## scenario_context ## ]]
# {scenario_context}
#
# [[ ## user_input ## ]]
# {user_input}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## next_thought ## ]]
# {next_thought}
#
# [[ ## next_tool_name ## ]]
# {next_tool_name}        # note: the value you produce must exactly match (no extra characters) one of: classify_input; search_prompts; update_prompt; finish
#
# [[ ## next_tool_args ## ]]
# {next_tool_args}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Respond as a D&D player character using the supplied scenario and behaviour instructions.
#
#         You are an Agent. In each episode, you will be given the fields `instruct_prompt`, `scenario_context`, `user_input` as input. And you can see your past trajectory so far.
#         Your goal is to use one or more of the supplied tools to collect any necessary information for producing `response`.
#
#         To do this, you will interleave next_thought, next_tool_name, and next_tool_args in each turn, and also when finishing the task.
#         After each tool call, you receive a resulting observation, which gets appended to your trajectory.
#
#         When writing next_thought, you may reason about the current situation and plan for future steps.
#         When selecting the next_tool_name and its next_tool_args, the tool must be one of:
#
#         (1) classify_input, whose description is <desc>Classify a player's input into a D&D behaviour category.</desc>. It takes arguments {'context': {'type': 'string'}, 'query': {'type': 'string'}, 'user_id': {'type': 'string', 'default': 'default_user'}}.
#         (2) search_prompts, whose description is <desc>Find the instruction text for a classified player behaviour.</desc>. It takes arguments {'prompt_class': {'type': 'string'}, 'context': {'type': 'string'}, 'query': {'type': 'string'}, 'user_id': {'type': 'string', 'default': 'default_user'}, 'limit': {'type': 'integer', 'default': 4}}.
#         (3) update_prompt, whose description is <desc>Append retrieved instructions to the current agent prompt.</desc>. It takes arguments {'context': {'type': 'string'}, 'query': {'type': 'string'}, 'instruct_prompt': {'type': 'string'}, 'prompt_text': {'type': 'string'}, 'new_prompt': {'type': 'string', 'default': ''}}.
#         (4) finish, whose description is <desc>Marks the task as complete. That is, signals that all information for producing the outputs, i.e. `response`, are now available to be extracted.</desc>. It takes arguments {}.
#         When providing `next_tool_args`, the value inside the field must be in JSON format
#
#
# User message:
#
# [[ ## instruct_prompt ## ]]
# You are playing a Dungeons & Dragons scene.
# Character: Alice, a dwarf barbarian.
# The instructions for how to play the role of a D&D player are as follows. This is a short scenario in which you play the role of a character named Alice. This scenario is structured as a Dungeons & Dragons game. The goal is to be consistent, but creative. It is important to play the role of a Dungeons & Dragons player as accurately as possible, i.e., by responding in ways that you think it is likely a player would respond, and taking into account all information that you have. It is important that you collaborate with with the user who is the other player, on the task at hand.Always use first-person limited perspective.
# Stay in character and reply with only the next spoken turn.
#
# [[ ## scenario_context ## ]]
# This D&D short scenario specifically concerns a rat infestation.It is set in the craft brewery Company and is in dire need of help.Alice and Bob are here to sort out a RAT INFESTATION in the brewery's BASEMENT.For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the breweryAt the beginning of this adventure Alice and Bobmeet in the Wizard Tower Brewing Company. These two adventurersDO NOT know each other AT FIRST and need to get to know each other.The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.
#
# Recent turns:
# Bob: "Agreed. A magical lock or ward might be in place to deter... *sniffs the air* ...unwanted guests. Let me cast *Detect Magic* to check for residual enchantments."
# Alice: "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
# Bob: "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
#
# [[ ## user_input ## ]]
# "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
#
# [[ ## trajectory ## ]]
#
#
# Respond with the corresponding output fields, starting with the field `[[ ## next_thought ## ]]`, then `[[ ## next_tool_name ## ]]` (must be formatted as a valid Python Literal['classify_input', 'search_prompts', 'update_prompt', 'finish']), then `[[ ## next_tool_args ## ]]` (must be formatted as a valid Python dict[str, Any]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## next_thought ## ]]
# "Lead the way, Bob. If the magic reveals anything worth breaking, I'll smash it. But if it's just a regular lock… well, I've torn down worse in a dwarven mine."
#
# [[ ## next_tool_name ## ]]
# finish
#
# [[ ## next_tool_args ## ]]
# {}
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-07-02T15:41:10.693388]
#
# System message:
#
# Your input fields are:
# 1. `instruct_prompt` (str):
# 2. `scenario_context` (str):
# 3. `user_input` (str):
# 4. `trajectory` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `response` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## instruct_prompt ## ]]
# {instruct_prompt}
#
# [[ ## scenario_context ## ]]
# {scenario_context}
#
# [[ ## user_input ## ]]
# {user_input}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## response ## ]]
# {response}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Respond as a D&D player character using the supplied scenario and behaviour instructions.
#
#
# User message:
#
# [[ ## instruct_prompt ## ]]
# You are playing a Dungeons & Dragons scene.
# Character: Alice, a dwarf barbarian.
# The instructions for how to play the role of a D&D player are as follows. This is a short scenario in which you play the role of a character named Alice. This scenario is structured as a Dungeons & Dragons game. The goal is to be consistent, but creative. It is important to play the role of a Dungeons & Dragons player as accurately as possible, i.e., by responding in ways that you think it is likely a player would respond, and taking into account all information that you have. It is important that you collaborate with with the user who is the other player, on the task at hand.Always use first-person limited perspective.
# Stay in character and reply with only the next spoken turn.
#
# [[ ## scenario_context ## ]]
# This D&D short scenario specifically concerns a rat infestation.It is set in the craft brewery Company and is in dire need of help.Alice and Bob are here to sort out a RAT INFESTATION in the brewery's BASEMENT.For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the breweryAt the beginning of this adventure Alice and Bobmeet in the Wizard Tower Brewing Company. These two adventurersDO NOT know each other AT FIRST and need to get to know each other.The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.
#
# Recent turns:
# Bob: "Agreed. A magical lock or ward might be in place to deter... *sniffs the air* ...unwanted guests. Let me cast *Detect Magic* to check for residual enchantments."
# Alice: "Keep your eyes peeled, Bob. If the magic shows anything worth breaking, I’ll smash it. But if it’s just a regular lock… well, I’ve torn down worse in a dwarven mine."
# Bob: "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
#
# [[ ## user_input ## ]]
# "Then let's not dawdle, Alice. If the door's enchanted, I'll handle the magic—your expertise with physical locks is exactly why we're paired. Shall we?"
#
# [[ ## trajectory ## ]]
# [[ ## thought_0 ## ]]
# "Lead the way, Bob. If the magic reveals anything worth breaking, I'll smash it. But if it's just a regular lock… well, I've torn down worse in a dwarven mine."
#
# [[ ## tool_name_0 ## ]]
# finish
#
# [[ ## tool_args_0 ## ]]
# {}
#
# [[ ## observation_0 ## ]]
# Completed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## response ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Alice's response reflects her confidence in her physical prowess and her trust in Bob's magical expertise. As a dwarf barbarian, she's pragmatic and straightforward, acknowledging the value of both their skills while expressing her readiness to tackle whatever lies ahead. Her mention of "torn down worse in a dwarven mine" underscores her background and reinforces her character's no-nonsense attitude.
#
# [[ ## response ## ]]
# "Lead the way, Bob. If the magic reveals anything worth breaking, I'll smash it. But if it's just a regular lock… well, I've torn down worse in a dwarven mine."
#
# [[ ## completed ## ]]
