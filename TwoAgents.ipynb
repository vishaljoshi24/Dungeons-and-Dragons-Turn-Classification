# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/Dungeons-and-Dragons-Turn-Classification/blob/main/simple_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b Codex-Branch 'https://github.com/vishaljoshi24/Dungeons-and-Dragons-Turn-Classification/'
# Out:
# Cloning into '''...
# fatal: protocol ''https' is not supported

# %%
# !pip install dspy

# %%
import argparse

# %%
from modules import AgentProfile, TwoAgentConversation, configure_lm

# %%
DEFAULT_SCENARIO = (
    "Charlie owns the Wizard Tower Brewing Company. Alice and Bob are adventurers "
    "asked to investigate a rat infestation in the brewery basement. Charlie warns "
    "them that simply charging downstairs may be dangerous."
)

# %%
def build_conversation() -> TwoAgentConversation:
    alice = AgentProfile(
        name="Alice",
        character="Alice, a direct dwarf barbarian who prefers practical action.",
        instructions=(
            "Push the scene forward, cooperate with the other player, and suggest "
            "clear actions when the group needs momentum."
        ),
    )
    bob = AgentProfile(
        name="Bob",
        character="Bob, a careful wizard who asks questions before taking risks.",
        instructions=(
            "Respond thoughtfully, gather useful information, and collaborate with "
            "the other player before committing to dangerous actions."
        ),
    )
    return TwoAgentConversation(
        agent_a=alice,
        agent_b=bob,
        scenario=DEFAULT_SCENARIO,
    )

# %%
parser = argparse.ArgumentParser(description="Run two D&D DSPy agents together.")

# %%
parser.add_argument(
    "--opening-message",
    default="I think we should inspect the basement door before we rush in.",
    help="The first turn spoken by Alice.",
)
# Out:
# _StoreAction(option_strings=['--opening-message'], dest='opening_message', nargs=None, const=None, default='I think we should inspect the basement door before we rush in.', type=None, choices=None, required=False, help='The first turn spoken by Alice.', metavar=None, deprecated=False)

# %%
parser.add_argument(
    "--rounds",
    type=int,
    default=4,
    help="Number of replies to generate after the opening message.",
)
# Out:
# _StoreAction(option_strings=['--rounds'], dest='rounds', nargs=None, const=None, default=4, type=<class 'int'>, choices=None, required=False, help='Number of replies to generate after the opening message.', metavar=None, deprecated=False)

# %%
parser.add_argument("--model", default="ollama_chat/qwen3:8b")
# Out:
# _StoreAction(option_strings=['--model'], dest='model', nargs=None, const=None, default='ollama_chat/qwen3:8b', type=None, choices=None, required=False, help=None, metavar=None, deprecated=False)

# %%
parser.add_argument("--api-base", default="http://localhost:11434")
# Out:
# _StoreAction(option_strings=['--api-base'], dest='api_base', nargs=None, const=None, default='http://localhost:11434', type=None, choices=None, required=False, help=None, metavar=None, deprecated=False)

# %%
args = parser.parse_args([])

# %%
configure_lm(model=args.model, api_base=args.api_base)

# %%
conversation = build_conversation()
# Out:
# 2026/06/30 12:16:53 WARNING dspy.primitives.base_module: There is a mismatch of python version between saved model and current environment. You saved with `python==3.12`, but now you have `python==3.14`. This might cause errors or performance downgrade on the loaded model, please consider loading the model in the same environment as the saving environment.
# 2026/06/30 12:16:53 WARNING dspy.primitives.base_module: There is a mismatch of python version between saved model and current environment. You saved with `python==3.12`, but now you have `python==3.14`. This might cause errors or performance downgrade on the loaded model, please consider loading the model in the same environment as the saving environment.

# %%
for turn in conversation.run(args.opening_message, rounds=args.rounds):
    print(turn)
