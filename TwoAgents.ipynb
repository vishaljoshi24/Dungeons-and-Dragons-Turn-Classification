# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/DungeonsAndDragonsTurnClassification/blob/Codex-Branch/TwoAgents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b Codex-Branch https://github.com/vishaljoshi24/DungeonsAndDragonsTurnClassification/
# %cd /content/DungeonsAndDragonsTurnClassification
# Out:
# [WinError 3] The system cannot find the path specified: '/content/DungeonsAndDragonsTurnClassification'
# C:\Users\jackj\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification
# Cloning into 'DungeonsAndDragonsTurnClassification'...

# %%
# !pip install dspy

# %%
import argparse

# %%
from modules import  (
    AgentProfile,
    TwoAgentConversation,
    configure_lm,
    PromptTool,
    InstructedChatbot
)

# %%
DEFAULT_SCENARIO = (
    'This D&D short scenario specifically concerns a rat infestation.'
'It is set in the craft brewery Company and is in dire need of help.'
'Alice and Bob are here to sort out a RAT INFESTATION in the brewery\'s BASEMENT.'
'For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the brewery'
'At the beginning of this adventure Alice and Bob'
'meet in the Wizard Tower Brewing Company. These two adventurers'
'DO NOT know each other AT FIRST and need to get to know each other.'
'The Charlie hands out pints of Ale to Alice and Bob as they get to know each other.'
)

# %%
instructions_path = "instructions.xlsx"
prompt_tool = PromptTool(prompts_path=instructions_path)
# Out:
# 2026/06/30 14:00:57 WARNING dspy.primitives.base_module: There is a mismatch of python version between saved model and current environment. You saved with `python==3.12`, but now you have `python==3.14`. This might cause errors or performance downgrade on the loaded model, please consider loading the model in the same environment as the saving environment.

# %%
def build_conversation() -> TwoAgentConversation:
    alice = AgentProfile(
        name="Alice",
        character="Alice, a dwarf barbarian.",
        instructions=(
          'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        'play the role of a character named Alice. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with with the user who is the '
        'other player, on the task at hand.'
        'Always use first-person limited perspective.'
        ),
    )
    bob = AgentProfile(
        name="Bob",
        character="Bob, a wizard.",
        instructions=(
        'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        'play the role of a character named Bob. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with with the user who is the '
        'other player, on the task at hand.'
        'Always use first-person limited perspective.'
        ),
    )
    return TwoAgentConversation(
        agent_a=alice,
        agent_b=bob,
        scenario=DEFAULT_SCENARIO,
        chatbot_a=InstructedChatbot(prompt_tool=prompt_tool),
        chatbot_b=InstructedChatbot(prompt_tool=prompt_tool),
    )

# %%
parser = argparse.ArgumentParser(description="Run two D&D DSPy agents together.")

# %%
parser.add_argument(
    "--opening-message",
    default="I think we should inspect the basement door before we rush in.",
    help="The first turn spoken by Alice.",
)
# Out:
# _StoreAction(option_strings=['--opening-message'], dest='opening_message', nargs=None, const=None, default='I think we should inspect the basement door before we rush in.', type=None, choices=None, required=False, help='The first turn spoken by Alice.', metavar=None, deprecated=False)

# %%
parser.add_argument(
    "--rounds",
    type=int,
    default=4,
    help="Number of replies to generate after the opening message.",
)
# Out:
# _StoreAction(option_strings=['--rounds'], dest='rounds', nargs=None, const=None, default=4, type=<class 'int'>, choices=None, required=False, help='Number of replies to generate after the opening message.', metavar=None, deprecated=False)

# %%
parser.add_argument("--model", default="ollama_chat/qwen3:8b")
# Out:
# _StoreAction(option_strings=['--model'], dest='model', nargs=None, const=None, default='ollama_chat/qwen3:8b', type=None, choices=None, required=False, help=None, metavar=None, deprecated=False)

# %%
parser.add_argument("--api-base", default="http://localhost:11434")
# Out:
# _StoreAction(option_strings=['--api-base'], dest='api_base', nargs=None, const=None, default='http://localhost:11434', type=None, choices=None, required=False, help=None, metavar=None, deprecated=False)

# %%
args = parser.parse_args([])

# %%
configure_lm(model=args.model, api_base=args.api_base)

# %%
conversation = build_conversation()

# %%
for turn in conversation.run(args.opening_message, rounds=args.rounds):
    print(turn)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File C:\Program Files\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:208, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     207 try:
# --> 208     response = sync_httpx_client.post(
#     209         url=api_base,
#     210         headers=headers,
#     211         data=(
#     212             signed_json_body
#     213             if signed_json_body is not None
#     214             else json.dumps(data)
#     215         ),
#     216         timeout=timeout,
#     217         stream=stream,
#     218         logging_obj=logging_obj,
#     219     )
#     220 except httpx.HTTPStatusError as e:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:900, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     899 except Exception as e:
# --> 900     raise e
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:879, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     876     req = self.client.build_request(
#     877         "POST", url, data=request_data, json=json, params=params, headers=headers, files=files, content=request_content  # type: ignore
#     878     )
# --> 879 response = self.client.send(req, stream=stream)
#     880 response.raise_for_status()
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File C:\Program Files\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\main.py:3408, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3401     api_key = (
#    3402         api_key
#    3403         or litellm.ollama_key
#    3404         or os.environ.get("OLLAMA_API_KEY")
#    3405         or litellm.api_key
#    3406     )
# -> 3408     response = base_llm_http_handler.completion(
#    3409         model=model,
#    3410         stream=stream,
#    3411         messages=messages,
#    3412         acompletion=acompletion,
#    3413         api_base=api_base,
#    3414         model_response=model_response,
#    3415         optional_params=optional_params,
#    3416         litellm_params=litellm_params,
#    3417         shared_session=shared_session,
#    3418         custom_llm_provider="ollama_chat",
#    3419         timeout=timeout,
#    3420         headers=headers,
#    3421         encoding=encoding,
#    3422         api_key=api_key,
#    3423         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3424         client=client,
#    3425     )
#    3427 elif custom_llm_provider == "triton":
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:511, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     509     sync_httpx_client = client
# --> 511 response = self._make_common_sync_call(
#     512     sync_httpx_client=sync_httpx_client,
#     513     provider_config=provider_config,
#     514     api_base=api_base,
#     515     headers=headers,
#     516     data=data,
#     517     signed_json_body=signed_json_body,
#     518     timeout=timeout,
#     519     litellm_params=litellm_params,
#     520     logging_obj=logging_obj,
#     521 )
#     522 return provider_config.transform_response(
#     523     model=model,
#     524     raw_response=response,
#    (...)    533     json_mode=json_mode,
#     534 )
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:235, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     234 except Exception as e:
# --> 235     raise self._handle_error(e=e, provider_config=provider_config)
#     236 break
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:3582, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    3576     raise BaseLLMException(
#    3577         status_code=status_code,
#    3578         message=error_text,
#    3579         headers=error_headers,
#    3580     )
# -> 3582 raise provider_config.get_error_class(
#    3583     error_message=error_text,
#    3584     status_code=status_code,
#    3585     headers=error_headers,
#    3586 )
#
# OllamaError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\utils.py:1250, in client.<locals>.wrapper(*args, **kwargs)
#    1249 # MODEL CALL
# -> 1250 result = original_function(*args, **kwargs)
#    1251 end_time = datetime.datetime.now()
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\main.py:3772, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3770 except Exception as e:
#    3771     ## Map to OpenAI Exception
# -> 3772     raise exception_type(
#    3773         model=model,
#    3774         custom_llm_provider=custom_llm_provider,
#    3775         original_exception=e,
#    3776         completion_kwargs=args,
#    3777         extra_kwargs=kwargs,
#    3778     )
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2328, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2327     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2328     raise e
#    2329 else:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2297, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2296 if hasattr(original_exception, "request"):
# -> 2297     raise APIConnectionError(
#    2298         message="{} - {}".format(exception_provider, error_str),
#    2299         llm_provider=custom_llm_provider,
#    2300         model=model,
#    2301         request=getattr(original_exception, "request", None),
#    2302     )
#    2303 else:
#
# APIConnectionError: litellm.APIConnectionError: Ollama_chatException - [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for turn in conversation.run(args.opening_message, rounds=args.rounds):
#       2     print(turn)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\modules.py:175, in TwoAgentConversation.run(self, opening_message, rounds)
#     168 for turn_index in range(rounds):
#     169     speaker, chatbot = (
#     170         (self.agent_b, self.chatbot_b)
#     171         if turn_index % 2 == 0
#     172         else (self.agent_a, self.chatbot_a)
#     173     )
# --> 175     prediction = chatbot(
#     176         instruct_prompt=self._agent_prompt(speaker),
#     177         scenario_context=self._context(),
#     178         user_input=next_message,
#     179     )
#     180     next_message = _prediction_label(prediction)
#     181     self.history.append(f"{speaker.name}: {next_message}")
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\primitives\module.py:110, in Module.__call__(self, *args, **kwargs)
#     106     self._set_lm_usage(tokens, output)
#     108     return output
# --> 110 return self.forward(*args, **kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\modules.py:139, in InstructedChatbot.forward(self, instruct_prompt, scenario_context, user_input)
#     138 def forward(self, instruct_prompt: str, scenario_context: str, user_input: str):
# --> 139     return self.react(
#     140         instruct_prompt=_as_text(instruct_prompt),
#     141         scenario_context=_as_text(scenario_context),
#     142         user_input=user_input,
#     143     )
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\primitives\module.py:110, in Module.__call__(self, *args, **kwargs)
#     106     self._set_lm_usage(tokens, output)
#     108     return output
# --> 110 return self.forward(*args, **kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\predict\react.py:100, in ReAct.forward(self, **input_args)
#      98 for idx in range(max_iters):
#      99     try:
# --> 100         pred = self._call_with_potential_trajectory_truncation(self.react, trajectory, **input_args)
#     101     except ValueError as err:
#     102         logger.warning(f"Ending the trajectory: Agent failed to select a valid tool: {_fmt_exc(err)}")
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\predict\react.py:148, in ReAct._call_with_potential_trajectory_truncation(self, module, trajectory, **input_args)
#     146 for _ in range(3):
#     147     try:
# --> 148         return module(
#     149             **input_args,
#     150             trajectory=self._format_trajectory(trajectory),
#     151         )
#     152     except ContextWindowExceededError:
#     153         logger.warning("Trajectory exceeded the context window, truncating the oldest tool call information.")
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\predict\predict.py:130, in Predict.__call__(self, *args, **kwargs)
#     127 if args:
#     128     raise ValueError(self._get_positional_args_error_message())
# --> 130 return super().__call__(**kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\primitives\module.py:110, in Module.__call__(self, *args, **kwargs)
#     106     self._set_lm_usage(tokens, output)
#     108     return output
# --> 110 return self.forward(*args, **kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\predict\predict.py:253, in Predict.forward(self, **kwargs)
#     251 else:
#     252     with settings.context(send_stream=None):
# --> 253         completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     255 return self._forward_postprocess(completions, signature, **kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:85, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      77 if (
#      78     isinstance(e, ContextWindowExceededError)
#      79     or isinstance(self, JSONAdapter)
#    (...)     82     # On context window exceeded error, already using JSONAdapter, or use_json_adapter_fallback is False
#      83     # we don't want to retry with a different adapter. Raise the original error instead of the fallback error.
#      84     raise e
# ---> 85 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\json_adapter.py:66, in JSONAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      58 def __call__(
#      59     self,
#      60     lm: BaseLM,
#    (...)     64     inputs: dict[str, Any],
#      65 ) -> list[dict[str, Any]]:
# ---> 66     result = self._json_adapter_call_common(lm, lm_kwargs, signature, demos, inputs, super().__call__)
#      67     if result:
#      68         return result
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\json_adapter.py:56, in JSONAdapter._json_adapter_call_common(self, lm, lm_kwargs, signature, demos, inputs, call_fn)
#      52 if _has_open_ended_mapping(signature) or (not self.use_native_function_calling and has_tool_calls) or not lm.supports_response_schema:
#      53     # We found that structured output mode doesn't work well with dspy.ToolCalls as output field.
#      54     # So we fall back to json mode if native function calling is disabled and ToolCalls is present.
#      55     lm_kwargs["response_format"] = {"type": "json_object"}
# ---> 56     return call_fn(lm, lm_kwargs, signature, demos, inputs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:84, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      75 from dspy.adapters.json_adapter import JSONAdapter
#      77 if (
#      78     isinstance(e, ContextWindowExceededError)
#      79     or isinstance(self, JSONAdapter)
#    (...)     82     # On context window exceeded error, already using JSONAdapter, or use_json_adapter_fallback is False
#      83     # we don't want to retry with a different adapter. Raise the original error instead of the fallback error.
# ---> 84     raise e
#      85 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:72, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      63 def __call__(
#      64     self,
#      65     lm: BaseLM,
#    (...)     69     inputs: dict[str, Any],
#      70 ) -> list[dict[str, Any]]:
#      71     try:
# ---> 72         return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      73     except Exception as e:
#      74         # fallback to JSONAdapter
#      75         from dspy.adapters.json_adapter import JSONAdapter
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\adapters\base.py:205, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#     202 processed_signature = self._call_preprocess(lm, lm_kwargs, signature, inputs)
#     203 inputs = self.format(processed_signature, demos, inputs)
# --> 205 outputs = lm(messages=inputs, **lm_kwargs)
#     206 return self._call_postprocess(processed_signature, signature, outputs, lm, lm_kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\clients\base_lm.py:129, in BaseLM.__call__(self, prompt, messages, **kwargs)
#     122 @with_callbacks
#     123 def __call__(
#     124     self,
#    (...)    127     **kwargs
#     128 ) -> list[dict[str, Any] | str]:
# --> 129     response = self.forward(prompt=prompt, messages=messages, **kwargs)
#     130     outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#     132     return outputs
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\clients\lm.py:186, in LM.forward(self, prompt, messages, **kwargs)
#     183 completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache)
#     185 try:
# --> 186     results = completion(
#     187         request=dict(model=self.model, messages=messages, **kwargs),
#     188         num_retries=self.num_retries,
#     189         cache=litellm_cache_args,
#     190     )
#     191 except LitellmContextWindowExceededError as e:
#     192     raise ContextWindowExceededError(model=self.model) from e
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\clients\cache.py:279, in request_cache.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     276 # Otherwise, compute and store the result
#     277 # Make a copy of the original request in case it's modified in place, e.g., deleting some fields
#     278 original_request = copy.deepcopy(modified_request)
# --> 279 result = fn(*args, **kwargs)
#     280 # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#     281 cache.put(original_request, result, ignored_args_for_cache_key, enable_memory_cache)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\dspy\clients\lm.py:392, in litellm_completion(request, num_retries, cache)
#     390 stream_completion = _get_stream_completion_fn(request, cache, sync=True, headers=headers)
#     391 if stream_completion is None:
# --> 392     return litellm.completion(
#     393         cache=cache,
#     394         num_retries=num_retries,
#     395         retry_strategy="exponential_backoff_retry",
#     396         headers=headers,
#     397         **request,
#     398     )
#     400 return stream_completion()
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\utils.py:1361, in client.<locals>.wrapper(*args, **kwargs)
#    1355     if (
#    1356         isinstance(e, openai.APIError)
#    1357         or isinstance(e, openai.Timeout)
#    1358         or isinstance(e, openai.APIConnectionError)
#    1359     ):
#    1360         kwargs["num_retries"] = num_retries
# -> 1361         return litellm.completion_with_retries(*args, **kwargs)
#    1362 elif (
#    1363     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#    1364     and context_window_fallback_dict
#    1365     and model in context_window_fallback_dict
#    1366     and not _is_litellm_router_call
#    1367 ):
#    1368     if len(args) > 0:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\main.py:3810, in completion_with_retries(*args, **kwargs)
#    3806 else:
#    3807     retryer = tenacity.Retrying(
#    3808         stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    3809     )
# -> 3810 return retryer(original_function, *args, **kwargs)
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File C:\Program Files\Python314\Lib\concurrent\futures\_base.py:447, in Future.result(self, timeout)
#     445     raise CancelledError()
#     446 elif self._state == FINISHED:
# --> 447     return self.__get_result()
#     449 self._condition.wait(timeout)
#     451 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\Python314\Lib\concurrent\futures\_base.py:396, in Future.__get_result(self)
#     394 if self._exception is not None:
#     395     try:
# --> 396         raise self._exception
#     397     finally:
#     398         # Break a reference cycle with the exception in self._exception
#     399         self = None
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\utils.py:1381, in client.<locals>.wrapper(*args, **kwargs)
#    1377 if logging_obj:
#    1378     logging_obj.failure_handler(
#    1379         e, traceback_exception, start_time, end_time
#    1380     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1381 raise e
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\utils.py:1250, in client.<locals>.wrapper(*args, **kwargs)
#    1248         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1249 # MODEL CALL
# -> 1250 result = original_function(*args, **kwargs)
#    1251 end_time = datetime.datetime.now()
#    1252 if _is_streaming_request(
#    1253     kwargs=kwargs,
#    1254     call_type=call_type,
#    1255 ):
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\main.py:3772, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3769     return response
#    3770 except Exception as e:
#    3771     ## Map to OpenAI Exception
# -> 3772     raise exception_type(
#    3773         model=model,
#    3774         custom_llm_provider=custom_llm_provider,
#    3775         original_exception=e,
#    3776         completion_kwargs=args,
#    3777         extra_kwargs=kwargs,
#    3778     )
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2328, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2326 if exception_mapping_worked:
#    2327     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2328     raise e
#    2329 else:
#    2330     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\Documents\GitHub\Dungeons-and-Dragons-Turn-Classification\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2297, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2295 exception_mapping_worked = True
#    2296 if hasattr(original_exception, "request"):
# -> 2297     raise APIConnectionError(
#    2298         message="{} - {}".format(exception_provider, error_str),
#    2299         llm_provider=custom_llm_provider,
#    2300         model=model,
#    2301         request=getattr(original_exception, "request", None),
#    2302     )
#    2303 else:
#    2304     raise APIConnectionError(
#    2305         message="{}\n{}".format(
#    2306             str(original_exception), traceback.format_exc()
#    (...)   2312         ),  # stub the request
#    2313     )
#
# APIConnectionError: litellm.APIConnectionError: Ollama_chatException - [WinError 10061] No connection could be made because the target machine actively refused it

# %%
import dspy
dspy.inspect_history()
